# %%
import os
import numpy as np
import pandas as pd

# %%
data_df = pd.read_csv("../data/train/train.tsv", sep="\t", header=None)
data_df
# Out:
#                                    0  \
# 0     wikipedia-24896-25-30-33-19-21
# 1      wikipedia-12728-224-5-7-42-44
# 2         wikipedia-28460-3-0-7-9-12
# 3       wikipedia-11479-37-24-26-3-5
# 4        wikipedia-15581-6-0-2-32-40
# ...                              ...
# 8995     wikipedia-5414-12-15-21-0-4
# 8996     wikipedia-10384-4-12-14-0-1
# 8997   wikipedia-25913-6-8-10-93-106
# 8998     wikitree-12062-15-0-3-46-47
# 8999    wikitree-21265-0-16-18-20-21
#
#                                                       1         2   3   4  \
# 0     영국에서 사용되는 스포츠 유틸리티 자동차의 브랜드로는 랜드로버(Land Rover)...      랜드로버  30  33
# 1     선거에서 민주당은 해산 전 의석인 230석에 한참 못 미치는 57석(지역구 27석,...       민주당   5   7
# 2     유럽 축구 연맹(UEFA) 집행위원회는 2014년 1월 24일에 열린 회의를 통해 ...  유럽 축구 연맹   0   7
# 3     용병 공격수 챠디의 부진과 시즌 초 활약한 강수일의 침체, 시즌 중반에 영입한 세르...       강수일  24  26
# 4     람캄행 왕은 1237년에서 1247년 사이 수코타이의 왕 퍼쿤 씨 인트라팃과 쓰엉 ...       람캄행   0   2
# ...

# %%
data_counts = dict(data_df[8].value_counts())
for k, v in list(data_counts.items())[::-1]:
    print(f"{k}: {v}")
# Out:
# 인물:사망_국가: 1
# 인물:사망_도시: 3
# 인물:출생_도시: 4
# 단체:자회사: 5
# 인물:나이: 5
# 인물:사망_원인: 7
# 인물:출생_국가: 8
# 인물:학교: 9
# 단체:구성원_수: 9
# 단체:주주: 11
# 인물:용의자: 11
# 인물:거주_주(도): 12
# 단체:해산일: 15
# 인물:종교: 15
# 단체:정치/종교성향: 18
# 단체:본사_주(도): 23
# 인물:거주_도시: 26
# 인물:거주_국가: 27
# 인물:출생_일시: 36
# 단체:모회사: 44
# 인물:사망_일시: 45
# 단체:창립자: 45
# 인물:형제/자매/남매: 52
# 인물:제작: 56
# 인물:기타_친족: 58
# 단체:창립일: 67
# 단체:하위_단체: 80
# 인물:자녀: 84
# 인물:배우자: 92
# 인물:별칭: 103
# 단체:본사_국가: 115
# 단체:본사_도시: 136
# 인물:부모님: 164
# 단체:제작: 165
# 인물:동료: 186
# 인물:출신성분/국적: 209
# 단체:별칭: 231
# 단체:상위_단체: 335
# 인물:직업/직함: 553
# 인물:소속단체: 680
# 단체:구성원: 815
# 관계_없음: 4440

# %%
count = 0
for data_row in data_df.to_numpy():
    if data_row[1].count(data_row[2]) > 1 or data_row[1].count(data_row[5]) > 1:
        print(data_row[2])
        print(data_row[5])
        print(data_row[1])
        print()
        count += 1
print(count)
# Out:
# 랜드로버
# 자동차
# 영국에서 사용되는 스포츠 유틸리티 자동차의 브랜드로는 랜드로버(Land Rover)와 지프(Jeep)가 있으며, 이 브랜드들은 자동차의 종류를 일컫는 말로 사용되기도 한다.
#
# 유럽 축구 연맹
# UEFA
# 유럽 축구 연맹(UEFA) 집행위원회는 2014년 1월 24일에 열린 회의를 통해 2017년 대회부터 UEFA U-21 축구 선수권 대회 참가국을 8개국에서 12개국으로 확대하기로 결정했다.
#
# 나고야 그램퍼스
# 토요타 자동차
# 2008년 이전 팀명칭은 나고야 그램퍼스 에이트였고 에이트는 나고야 시 표장에 있는 숫자(八)와 모기업 토요타 자동차의 브랜드를 상징하였으나, 2008년부터 에이트를 제외하고 팀 명칭을 나고야 그램퍼스로 호칭하고 있다.
#
# 메종 글래드 제주
# 제주
# 종합대상을 수상한 메종 글래드 제주를 운영하는 글래드 호텔앤리조트는, 1977년 삼호개발주식회사로 출발해 같은 해 오라 컨트리클럽을 개관, 1981년 제주그랜드호텔 개관 등 제주 발전사(史)의 한 흐름을 담당해왔으며 1992년에는 수도권 외 호텔로는 최초로 1000만달러 관광진흥탑을 수상, 2015년 대대적인 작업을 거쳐 제주그랜드호텔을 메종 글래드 제주로 리뉴얼 오픈했다.
#
# 문재인
# 더불어민주당
# 하지만 대한민국의 미투 운동에 더불어민주당의 일부 정계인사들이 연루되고, 문재인 정부의 초대 청와대 대변인이었던 박수현이 불륜설에 휩싸임과 함께 금융감독원장에 임명된 김기식이 여러 논란에 휩싸임과 동시에 더불어민주당원 댓글 조작 사건까지 불거지면서 다시 위기에 몰렸다.
#
# 알베르트 아인슈타인
# 물리학
# ‘슈타인’의 명칭은 물리학자인 알베르트 아인슈타인에서 따온 것이며, 상대성 이론 등의 물리학적 요소가 스토리 구조 내에 포함되어 있다.
#
# 포르쉐
# 자동차
# 스포츠 자동차만 만들던 포르쉐가 SUV를 만든다는 것에 자동차 평론가들은 의구심을 제기하기도 했다.
#
# UBS
# 스위스
# ...

# %%
data_df.loc[data_df[8] == "인물:사망_도시", :]
# Out:
#                                   0  \
# 1160   wikitree-63570-2-66-67-22-23
# 1847  wikipedia-13641-1-57-64-35-42
# 5877   wikitree-52052-1-73-73-54-59
#
#                                                       1         2   3   4  \
# 1160  12일 서울 관악경찰서는 지난달 31일 서울 관악구 봉천동에 있는 한 임대아파트에서...        김모  66  67
# 1847  내부 마케도니아 혁명 기구의 회원으로 활동했으며 1934년에는 프랑스 마르세유에서 ...  알렉산다르 1세  57  64
# 5877  22일 인천 계양 경찰서에 따르면 지난 21일 한 시민이 오전 9시 43분 인천시 ...         A  73  73
#
#              5   6   7         8
# 1160        서울  22  23  인물:사망_도시
# 1847  프랑스 마르세유  35  42  인물:사망_도시
# 5877    경인아라뱃길  54  59  인물:사망_도시
